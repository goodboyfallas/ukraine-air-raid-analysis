# %% [markdown]
# # Ukraine Air Raid Alerts - Exploratory Analysis
#
# This notebook explores the air raid alert dataset for Ukraine.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from src.data.loader import load_csv
from src.preprocessing.cleaning import full_clean
from src.analysis.features import build_features
from src.analysis.analytics import *

sns.set_style('whitegrid')
# %matplotlib inline

# %% [markdown]
# ## Load and Clean Data

# %%
df = load_csv()
df = full_clean(df)
df = build_features(df)
df.head()

# %% [markdown]
# ## Summary Statistics

# %%
stats = summary_stats(df)
stats

# %% [markdown]
# ## Alerts Over Time

# %%
from src.visualization.plotting import plot_alerts_over_time
plot_alerts_over_time(df, save=False)
plt.show()

# %% [markdown]
# ## Top Regions

# %%
from src.visualization.plotting import plot_top_regions
plot_top_regions(df, save=False)
plt.show()

# %% [markdown]
# ## Heatmap: Day of Week x Hour

# %%
from src.visualization.plotting import plot_weekday_heatmap
plot_weekday_heatmap(df, save=False)
plt.show()
